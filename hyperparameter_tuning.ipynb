# %% [markdown]
# # Info
#
# Train and deploy the SVD model into an Azure ML Workspace.

# %%
# Connect to workspace
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient
import yaml

with open('azure_config.yml', 'r') as file:
  azure_config = yaml.safe_load(file)

subscription_id = azure_config['azure_workspace_details']['sub_id']
resource_group = azure_config['azure_workspace_details']['rg_name']
workspace = azure_config['azure_workspace_details']['ws_name']

ml_client = MLClient(
  credential=DefaultAzureCredential(),
  subscription_id=subscription_id,
  resource_group_name=resource_group,
  workspace_name=workspace
)
# Out:
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %% [markdown]
# # Setup
#
# Azure ML Workspace runtime requirements for job: Environment and Compute Cluster

# %% [markdown]
# ## Conda Environment
#
# Keep an up-to-date Conda environment YAML configuration file under src folder. Create via cmd: `conda env export > conda-env.yml`

# %%
from azure.ai.ml.entities import Environment

env_name = 'svd-env'

try: 
  env = ml_client.environments.get(env_name, version=6)
  print(f"Existing environment named {env_name} already exists w/ version {env.version}")
except Exception: 
  print("Creating a new environment...")
  env_docker_conda = Environment(
    image="mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04",
    conda_file="./src/conda-env.yml",
    name="svd-env",
    description="Environment created for SVD modeling",
  )

  ml_client.environments.create_or_update(env_docker_conda)
# Out:
# Existing environment named svd-env already exists w/ version 6

# %% [markdown]
# ## Compute Cluster

# %%
from azure.ai.ml.entities import AmlCompute

# Name assigned to the compute cluster
cpu_compute_target = "aml-cluster"

try:
  cpu_cluster = ml_client.compute.get(cpu_compute_target)
  print(f"Using existing cluster named {cpu_compute_target}")
except Exception:
  print("Creating a new cpu compute target...")

  cpu_cluster = AmlCompute(
    name=cpu_compute_target,
    type="amlcompute",
    size="STANDARD_DS11_V2",
    min_instances=0,
    max_instances=2,
    idle_time_before_scale_down=120,
    tier="Dedicated",
  )

  cpu_cluster = ml_client.compute.begin_create_or_update(cpu_cluster)
# Out:
# Using existing cluster named aml-cluster

# %% [markdown]
# # Create Jobs
#
# Run job from script `svd_params.py` with local ratings parquet file (not bothering with registering data assets here). MLFlow in the script will log hyperparameters as well as the primary metric of RMSE.

# %% [markdown]
# ## Initial Run

# %%
from azure.ai.ml import command
from azure.ai.ml.entities import Data
from azure.ai.ml import Input, Output
from azure.ai.ml.constants import AssetTypes
from azure.ai.ml.sweep import Choice

experiment_name='svd_training'

job = command(
  code='./src',
  command='python train_svd_params.py --training_data ratings_combined.parquet --n_epochs ${{inputs.n_epochs}} --lr_all ${{inputs.lr_all}} --reg_all ${{inputs.reg_all}}',
  inputs={
    'n_epochs':20,
    'lr_all':0.005,
    'reg_all':0.02
  },
  environment='svd-env:6',
  compute='aml-cluster',
  display_name='svd-train',
  experiment_name=experiment_name
)

returned_job = ml_client.create_or_update(job)
aml_url = returned_job.studio_url
print("Job created at:", aml_url)
# Out:
# Your file exceeds 100 MB. If you experience low speeds, latency, or broken connections, we recommend using the AzCopyv10 tool for this file transfer.
#
# Example: azcopy copy 'C:\Users\ERC53\Github\letterboxd_svd\src' 'https://mlwec1770620049.blob.core.windows.net/7d15eee6-d179-4861-bd3c-a539a345de88-xvptjh9997ym1e5heaycmytory/src'
#
# See https://learn.microsoft.com/azure/storage/common/storage-use-azcopy-v10 for more information.
# Uploading src (449.59 MBs): 100%|##########| 449585420/449585420 [00:13<00:00, 34277625.21it/s]
# Job created at: https://ml.azure.com/runs/magenta_arch_94q2nyw0jt?wsid=/subscriptions/d11a1a82-5001-4aca-ad0c-9632beca4a9f/resourcegroups/rg-ec/workspaces/mlw-ec&tid=e39e8e96-a6c1-42d4-9c0f-bf7830e0d1e6

# %% [markdown]
# ## Sweep Job for Hyperparameter Tuning
#
# Will use discrete search space for the following hyperparameters:
#
# * `n_epochs` (20 was default) = [20, 50]
# * `lr_all` (0.005 was default) = [0.001, 0.005, 0.01, 0.1, 0.2]
# * `reg_all` (0.02 was default)= [0.001, 0.02, 0.1, 1, 10]

# %%
from azure.ai.ml.sweep import Choice
from azure.ai.ml.sweep import MedianStoppingPolicy

cmd_job_for_sweep = job(
  n_epochs=Choice(values=[20, 50]),
  lr_all=Choice(values=[0.001, 0.005, 0.01, 0.1, 0.2]),
  reg_all=Choice(values=[0.001, 0.02, 0.1, 1, 10])
)

sweep_job = cmd_job_for_sweep.sweep(
  compute="aml-cluster",
  sampling_algorithm="grid",
  primary_metric="RMSE",
  goal="Minimize"
)
sweep_job.set_limits(
  max_total_trials=50,
  max_concurrent_trials=4,
  timeout=7200
)
sweep_job.experiment_name="svd-sweep"
sweep_job.early_termination = MedianStoppingPolicy(delay_evaluation = 5, evaluation_interval = 1)

returned_sweep_job = ml_client.create_or_update(sweep_job)
aml_url = returned_sweep_job.studio_url
print("Sweep job created at:", aml_url)
# Out:
# Sweep job created at: https://ml.azure.com/runs/joyful_match_tc993gjfsp?wsid=/subscriptions/d11a1a82-5001-4aca-ad0c-9632beca4a9f/resourcegroups/rg-ec/workspaces/mlw-ec&tid=e39e8e96-a6c1-42d4-9c0f-bf7830e0d1e6

# %%
from azure.ai.ml.entities import Model
from azure.ai.ml.constants import AssetTypes

# Register best performing model
job_name = returned_sweep_job.name

run_model = Model(
    path=f"azureml://jobs/{job_name}/outputs/artifacts/paths/model/",
    name="mlflow-svd",
    description="Best model picked from sweep job",
    type=AssetTypes.MLFLOW_MODEL,
)
ml_client.models.create_or_update(run_model)
# Out:
# ActivityCompleted: Activity=Model.CreateOrUpdate, HowEnded=Failure, Duration=1089.2 [ms], Exception=HttpResponseError, ErrorCategory=UserError, ErrorMessage=(UserError) The request is invalid.
# Code: UserError
# Message: The request is invalid.
# Exception Details:	(ModelJobNameInvalid) The provided Job name svd-train_37 is invalid or does not exist.
# 	Code: ModelJobNameInvalid
# 	Message: The provided Job name svd-train_37 is invalid or does not exist.
# Additional Information:Type: ComponentName
# Info: {
#     "value": "managementfrontend"
# }Type: Correlation
# Info: {
#     "value": {
#         "operation": "418479843d95b204fd226abc1eb462d7",
#         "request": "d08ffb91fb5ad25f"
#     }
# }Type: Environment
# Info: {
#     "value": "eastus"
# }Type: Location
# Info: {
#     "value": "eastus"
# }Type: Time
# Info: {
#     "value": "2025-12-30T00:38:58.7836432+00:00"
# }
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# Cell In[11], line 13
#       5 job_name = 'svd-train_37'
#       7 run_model = Model(
#       8     path=f"azureml://jobs/{job_name}/outputs/artifacts/paths/model/",
#       9     name="mlflow-svd",
#      10     description="Best model picked from sweep job",
#      11     type=AssetTypes.MLFLOW_MODEL,
#      12 )
# ---> 13 ml_client.models.create_or_update(run_model)
#
# File c:\Users\ERC53\AppData\Local\anaconda3\envs\aml\Lib\site-packages\azure\ai\ml\_telemetry\activity.py:288, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     284     with tracer.start_as_current_span(ACTIVITY_SPAN):
#     285         with log_activity(
#     286             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     287         ):
# --> 288             return f(*args, **kwargs)
#     289 elif hasattr(logger, "package_logger"):
#     290     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File c:\Users\ERC53\AppData\Local\anaconda3\envs\aml\Lib\site-packages\azure\ai\ml\operations\_model_operations.py:301, in ModelOperations.create_or_update(self, model)
#     299     log_and_raise_error(ex)
#     300 else:
# --> 301     raise ex
#
# File c:\Users\ERC53\AppData\Local\anaconda3\envs\aml\Lib\site-packages\azure\ai\ml\operations\_model_operations.py:289, in ModelOperations.create_or_update(self, model)
#     282     if str(e) == ASSET_PATH_ERROR:
#     283         raise AssetPathException(
#     284             message=CHANGED_ASSET_PATH_MSG,
#     285             target=ErrorTarget.MODEL,
#     286             no_personal_data_message=CHANGED_ASSET_PATH_MSG_NO_PERSONAL_DATA,
#     287             error_category=ErrorCategory.USER_ERROR,
#     288         ) from e
# --> 289     raise e
#     291 model = Model._from_rest_object(result)
#     292 if auto_increment_version and indicator_file:
#
# File c:\Users\ERC53\AppData\Local\anaconda3\envs\aml\Lib\site-packages\azure\ai\ml\operations\_model_operations.py:268, in ModelOperations.create_or_update(self, model)
#     258 try:
#     259     cont_token = self._scope_kwargs.pop("continuation_token", None)  # type: Optional[str]
#     260     result = (
#     261         self._begin_create_or_update_registry_model(
#     262             name,
#     263             version,
#     264             model_version_resource,
#     265             cont_token,
#     266         )
#     267         if self._registry_name
# --> 268         else self._model_versions_operation.create_or_update(
#     269             name=name,
#     270             version=version,
#     271             body=model_version_resource,
#     272             workspace_name=self._workspace_name,
#     273             **self._scope_kwargs,
#     274         )
#     275     )
#     277     if not result and self._registry_name:
#     278         result = self._get(name=str(model.name), version=model.version)
#
# File c:\Users\ERC53\AppData\Local\anaconda3\envs\aml\Lib\site-packages\azure\core\tracing\decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File c:\Users\ERC53\AppData\Local\anaconda3\envs\aml\Lib\site-packages\azure\ai\ml\_restclient\v2023_08_01_preview\operations\_model_versions_operations.py:650, in ModelVersionsOperations.create_or_update(self, resource_group_name, workspace_name, name, version, body, **kwargs)
#     648     map_error(status_code=response.status_code, response=response, error_map=error_map)
#     649     error = self._deserialize.failsafe_deserialize(_models.ErrorResponse, pipeline_response)
# --> 650     raise HttpResponseError(response=response, model=error, error_format=ARMErrorFormat)
#     652 if response.status_code == 200:
#     653     deserialized = self._deserialize('ModelVersion', pipeline_response)
#
# HttpResponseError: (UserError) The request is invalid.
# Code: UserError
# Message: The request is invalid.
# Exception Details:	(ModelJobNameInvalid) The provided Job name svd-train_37 is invalid or does not exist.
# 	Code: ModelJobNameInvalid
# 	Message: The provided Job name svd-train_37 is invalid or does not exist.
# Additional Information:Type: ComponentName
# Info: {
#     "value": "managementfrontend"
# }Type: Correlation
# Info: {
#     "value": {
#         "operation": "418479843d95b204fd226abc1eb462d7",
#         "request": "d08ffb91fb5ad25f"
#     }
# }Type: Environment
# Info: {
#     "value": "eastus"
# }Type: Location
# Info: {
#     "value": "eastus"
# }Type: Time
# Info: {
#     "value": "2025-12-30T00:38:58.7836432+00:00"
# }
